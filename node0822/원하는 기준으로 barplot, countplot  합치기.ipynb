# %%
# Pandas, Numpy, Matplotlib, Seaborn을 호출
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import seaborn as sns

# %%
# sales_data 변수를 만들고 각 데이터 값을 할당
sales_data = pd.read_csv('~/aiffel/data_analysis_basic/data/sales_6.csv')

# 변수 sales_data의 head 값 확인하기
sales_data.head()
# Out:
#       install  Time_stamp   Game_Name Status  Payment   Customer_ID
# 0  2022-01-08  2022-02-05  MineGround   play     4900    facilis140
# 1  2022-01-05  2022-02-17  MineGround   play    29900    debitis994
# 2  2022-01-29  2022-02-06  MineGround   play     4900   possimus246
# 3  2022-01-09  2022-02-05  MineGround   play      900  occaecati138
# 4  2022-01-08  2022-02-01  MineGround   play      900   corrupti325

# %%
sales_data['date'] = sales_data['Time_stamp'].str[:7]
sales_data.head()
sales_data['date'].value_counts()
# Out:
# 2022-03    50465
# 2022-02    49380
# Name: date, dtype: int64

# %%
# 월별 고객 수 현황 시각화하기
ax = sns.countplot(data=sales_data, x='date')

containers = ax.containers[0]
ax.bar_label(containers, label_type='center')

# containers0 = ax.containers[-1]
# ax.bar_label(containers0, label_type='center')

plt.title('Customer By Month')

plt.show()

# %%
grouped = sales_data['Status'].groupby([sales_data['date'], sales_data['Game_Name']]).count()
grouped
# Out:
# date     Game_Name
# 2022-02  MineGround       27721
#          SoccerManager    21659
# 2022-03  MineGround       32192
#          SoccerManager    18273
# Name: Status, dtype: int64

# %%
ax = sns.barplot(data=grouped.reset_index(), x= 'date', y='Status', hue ='Game_Name')

# %%
# 월별 각 게임 고객 수 시각화하기
ax = sns.barplot(data=grouped.reset_index(), x='date', y='Status', hue='Game_Name')

containers = ax.containers[1]
containers0 = ax.containers[0]
ax.bar_label(containers, label_type='center')
ax.bar_label(containers0, label_type='center') # 파란색 바 라벨
plt.title('Customer Count by Game')
plt.show()

# %%
sales_data['Status'].value_counts()
# Out:
# play       84821
# install    15024
# Name: Status, dtype: int64

# %%
ax = sns.countplot(data = sales_data , x = 'date',hue = 'Status')

containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues],label_type='center')
containers0 = ax.containers[-1]
ax.bar_label(containers0, labels=[f'{x:,.0f}' for x in containers0.datavalues], label_type='center')
plt.title('Customer By Real Play')

plt.show()

# %%
temp_data = sales_data[sales_data['Payment'] !=0]
temp_data['date'].value_counts()
# Out:
# 2022-02    8542
# 2022-03    6898
# Name: date, dtype: int64

# %%
# 월별 결제 횟수 시각화하기
ax = sns.countplot(data=temp_data, x='date')
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('Payment Counts by Month')
plt.show()

# %%
grouped = temp_data['Payment'].groupby([temp_data['date'], temp_data['Game_Name']]).count()
grouped
# Out:
# date     Game_Name
# 2022-02  MineGround       4318
#          SoccerManager    4224
# 2022-03  MineGround       3762
#          SoccerManager    3136
# Name: Payment, dtype: int64

# %%
# 각 게임별 결제 건수 시각화하기
ax = sns.barplot(data=grouped.reset_index(), x='date', y='Payment', hue='Game_Name')

containers = ax.containers[-1]
containers0 = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
ax.bar_label(containers0, labels=[f'{x:,.0f}' for x in containers0.datavalues], label_type='center')
plt.title('Payment Count By Game')
plt.show()

# %%
# 코드를 직접 작성해 보세요. 
# 각 게임별 결제 금액 시각화하기
# [[YOUR CODE]]
ax = sns.barplot(data=grouped.reset_index(),x='date', y='Payment', hue="Game_Name")

containers = ax.containers[-1]
containers0 = ax.containers[0]
ax.bar_label(containers, labels=[f'{x :,.0f}' for x in containers.datavalues], label_type= 'center')

ax.bar_label(containers0, labels=[f'{x :,.0f}' for x in containers.datavalues], label_type= 'center')

plt.title('Payment Count By Game')
plt.show()

# %%
# player_data변수를 만들고 sales_data에서 Status가 play인 고객들만 골라내 할당하기
player_data = sales_data[sales_data['Status'] == 'play'].copy()
player_data
# Out:
#           install  Time_stamp      Game_Name Status  Payment   Customer_ID  \
# 0      2022-01-08  2022-02-05     MineGround   play     4900    facilis140
# 1      2022-01-05  2022-02-17     MineGround   play    29900    debitis994
# 2      2022-01-29  2022-02-06     MineGround   play     4900   possimus246
# 3      2022-01-09  2022-02-05     MineGround   play      900  occaecati138
# 4      2022-01-08  2022-02-01     MineGround   play      900   corrupti325
# ...           ...         ...            ...    ...      ...           ...
# 84816  2022-03-06  2022-03-11  SoccerManager   play        0        sed821
# 84817  2022-03-20  2022-03-23  SoccerManager   play        0     minima581
# 84818  2022-03-25  2022-03-27  SoccerManager   play        0      harum162
# 84819  2022-03-15  2022-03-18  SoccerManager   play        0    eveniet498
# 84820  2022-03-12  2022-03-17  SoccerManager   play        0       quis906
#
#           data     date
# 0      2022-02  2022-02
# 1      2022-02  2022-02
# 2      2022-02  2022-02
# 3      2022-02  2022-02
# 4      2022-02  2022-02
# ...        ...      ...
# 84816  2022-03  2022-03
# 84817  2022-03  2022-03
# 84818  2022-03  2022-03
# 84819  2022-03  2022-03
# 84820  2022-03  2022-03
#
# [84821 rows x 8 columns]

# %%
# plater_data에 install_date열을 만들고, install열 값의 7번째 값까지 입력
player_data['install_date'] = player_data['install'].str[:7]
player_data['play_date'] = player_data['Time_stamp'].str[:7]

# 주의해야 할 점은 SettingWithCopyWarning 경고가 나타나고 있습니다. 
# 이 경고는 데이터프레임의 일부 데이터를 추출하여 새로운 변수에 할당하고 
# 그 변수에서 데이터를 변경하는 경우 발생할 수 있는 경고입니다. 
# 이를 해결하기 위해서는 .copy()을 사용하여 명시적으로 데이터프레임의 일부를 수정하는 것이 좋습니다.

# %%
# plater_data에 type열을 만들고, install_date와 play_date열의 값이 같으면 New Player을 입력, 값이 다르면 Existing을 입력
player_data['type'] = np.where(player_data['install_date']==player_data['play_date'], 'New Player', 'Existing')

# %%
grouped = player_data['Status'].groupby([player_data['play_date'], player_data['type']]).count()
grouped
# Out:
# play_date  type
# 2022-02    Existing      28668
#            New Player    15480
# 2022-03    Existing      28207
#            New Player    12466
# Name: Status, dtype: int64

# %%
ax=sns.countplot(data=player_data, x='play_date', hue = 'type')

containers = ax.containers[-1]
containers0 = ax.containers[0]
ax.bar_label(containers, labels=[f'{x : ,.0f}' for x in containers.datavalues],label_type='center')
ax.bar_label(containers0, labels=[f'{x : ,.0f}' for x in containers.datavalues],label_type='center')
plt.title('Customer Type By Month')
plt.show()

# %%
# 코드를 직접 작성해 보세요. 
# 월별 신규 고객과 기존 고객의 결제 현황 살펴보기
# [[YOUR CODE]]
grouped = player_data['Payment'].groupby([player_data['play_date'], player_data['type']]).sum()
grouped
# Out:
# play_date  type
# 2022-02    Existing      50140500
#            New Player    30701300
# 2022-03    Existing      50140500
#            New Player    18220700
# Name: Payment, dtype: int64

# %%
# 각 게임별 결제 금액 월별 시각화하기
ax = sns.barplot(data=grouped.reset_index(), x='play_date', y='Payment', hue='type')
print(ax.containers)
containers = ax.containers[-2]
containers0 = ax.containers[-1]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
ax.bar_label(containers0, labels=[f'{x:,.0f}' for x in containers0.datavalues], label_type='center')
plt.title('Customer Type By Month')
plt.show()
# Out:
# [<BarContainer object of 2 artists>, <BarContainer object of 2 artists>]

# %%
ax = grouped.unstack().plot(kind='bar', stacked = True, grid=False, figsize=[6,6])
print(ax.containers)

containers = ax.containers[-1]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
containers0 = ax.containers[0]
ax.bar_label(containers0, labels=[f'{x:,.0f}' for x in containers0.datavalues], label_type='center')

plt.title('Payment by Type')
plt.show()
# Out:
# [<BarContainer object of 2 artists>, <BarContainer object of 2 artists>]

# %%
# play_date의 인덱스를 type으로 지정하기
payment_data = player_data.set_index('type', drop=True)
payment_data
# Out:
#                install  Time_stamp      Game_Name Status  Payment  \
# type
# Existing    2022-01-08  2022-02-05     MineGround   play     4900
# Existing    2022-01-05  2022-02-17     MineGround   play    29900
# Existing    2022-01-29  2022-02-06     MineGround   play     4900
# Existing    2022-01-09  2022-02-05     MineGround   play      900
# Existing    2022-01-08  2022-02-01     MineGround   play      900
# ...                ...         ...            ...    ...      ...
# New Player  2022-03-06  2022-03-11  SoccerManager   play        0
# New Player  2022-03-20  2022-03-23  SoccerManager   play        0
# New Player  2022-03-25  2022-03-27  SoccerManager   play        0
# New Player  2022-03-15  2022-03-18  SoccerManager   play        0
# New Player  2022-03-12  2022-03-17  SoccerManager   play        0
#
#              Customer_ID     data     date install_date play_date
# type
# Existing      facilis140  2022-02  2022-02      2022-01   2022-02
# Existing      debitis994  2022-02  2022-02      2022-01   2022-02
# Existing     possimus246  2022-02  2022-02      2022-01   2022-02
# Existing    occaecati138  2022-02  2022-02      2022-01   2022-02
# Existing     corrupti325  2022-02  2022-02      2022-01   2022-02
# ...                  ...      ...      ...          ...       ...
# New Player        sed821  2022-03  2022-03      2022-03   2022-03
# New Player     minima581  2022-03  2022-03      2022-03   2022-03
# New Player      harum162  2022-03  2022-03      2022-03   2022-03
# New Player    eveniet498  2022-03  2022-03      2022-03   2022-03
# New Player       quis906  2022-03  2022-03      2022-03   2022-03
#
# [84821 rows x 10 columns]

# %%
# 인덱스에서 Existing을 삭제하고 신규 고객들만 남기기
payment_data.drop('Existing', inplace=True)

# %%
# payment_data의 인덱스를 Payment로 지정하기
payment_data = payment_data.set_index('Payment')
print(payment_data.head())
# Payment_data의 인덱스에서 0을 삭제하고 결제 이력이 있는 고객만 남기기, 인덱스에서 0이면 결제이력이 없는 것이므로.
payment_data.drop(0, inplace=True)
print(payment_data.head())
payment_data = payment_data.reset_index()
print(payment_data.head())
# Out:
#             install  Time_stamp   Game_Name Status  Customer_ID     data  \
# Payment
# 9900     2022-02-06  2022-02-11  MineGround   play   dolorum016  2022-02
# 49900    2022-02-16  2022-02-17  MineGround   play       qui798  2022-02
# 900      2022-02-07  2022-02-08  MineGround   play  nesciunt993  2022-02
# 900      2022-02-03  2022-02-08  MineGround   play   ratione752  2022-02
# 900      2022-02-03  2022-02-06  MineGround   play     ullam478  2022-02
#
#             date install_date play_date
# Payment
# 9900     2022-02      2022-02   2022-02
# 49900    2022-02      2022-02   2022-02
# 900      2022-02      2022-02   2022-02
# 900      2022-02      2022-02   2022-02
# 900      2022-02      2022-02   2022-02
#             install  Time_stamp   Game_Name Status  Customer_ID     data  \
# Payment
# 9900     2022-02-06  2022-02-11  MineGround   play   dolorum016  2022-02
# 49900    2022-02-16  2022-02-17  MineGround   play       qui798  2022-02
# 900      2022-02-07  2022-02-08  MineGround   play  nesciunt993  2022-02
# 900      2022-02-03  2022-02-08  MineGround   play   ratione752  2022-02
# 900      2022-02-03  2022-02-06  MineGround   play     ullam478  2022-02
#
#             date install_date play_date
# Payment
# 9900     2022-02      2022-02   2022-02
# 49900    2022-02      2022-02   2022-02
# 900      2022-02      2022-02   2022-02
# 900      2022-02      2022-02   2022-02
# 900      2022-02      2022-02   2022-02
#    Payment     install  Time_stamp   Game_Name Status  Customer_ID     data  \
# 0     9900  2022-02-06  2022-02-11  MineGround   play   dolorum016  2022-02
# 1    49900  2022-02-16  2022-02-17  MineGround   play       qui798  2022-02
# 2      900  2022-02-07  2022-02-08  MineGround   play  nesciunt993  2022-02
# 3      900  2022-02-03  2022-02-08  MineGround   play   ratione752  2022-02
# 4      900  2022-02-03  2022-02-06  MineGround   play     ullam478  2022-02
#
#       date install_date play_date
# 0  2022-02      2022-02   2022-02
# 1  2022-02      2022-02   2022-02
# 2  2022-02      2022-02   2022-02
# 3  2022-02      2022-02   2022-02
# 4  2022-02      2022-02   2022-02

# %%
payment_data_02 = payment_data.set_index('play_date').loc['2022-02'].Payment.values
payment_data_03 = payment_data.set_index('play_date').loc['2022-03'].Payment.values
total_payment = np.array([payment_data_02, payment_data_03],dtype=object)
print(payment_data_02)
print(payment_data_03)
print(total_payment)
# Out:
# [ 9900 49900   900 ...   900  9900  4900]
# [  900  4900 29900 ...   900  4900  4900]
# [array([ 9900, 49900,   900, ...,   900,  9900,  4900])
#  array([  900,  4900, 29900, ...,   900,  4900,  4900])]

# %%
bins = np.linspace(0,50000,10)
plt.xlabel('Payment')
plt.ylabel('Count')
plt.hist(total_payment, bins, label=['2022-02', '2022-03'])
# Out:
# (array([[1879.,  651.,    0.,  312.,    0.,  172.,    0.,    0.,  163.],
#         [1107.,  374.,    0.,  196.,    0.,   78.,    0.,    0.,  108.]]),
#  array([    0.        ,  5555.55555556, 11111.11111111, 16666.66666667,
#         22222.22222222, 27777.77777778, 33333.33333333, 38888.88888889,
#         44444.44444444, 50000.        ]),
#  <a list of 2 BarContainer objects>)

# %%
# 코드를 직접 작성해 보세요. 


# play_date의 인덱스를 type으로 지정하기
payment_data = player_data.set_index('type', drop=True)
payment_data


# 인덱스에서 New_player을 삭제하고 기존 고객들만 남기기
payment_data.drop('New Player', inplace=True)


# payment_data의 인덱스를 Payment로 지정하기
payment_data = payment_data.set_index('Payment')


# Payment_data의 인덱스에서 0을 삭제하고 결제 이력이 있는 고객만 남기기
payment_data.drop(0, inplace=True)
payment_data = payment_data.reset_index()



# 고객의 결제이력을 월별로 구분하기
payment_data_02 = payment_data.set_index('play_date').loc['2022-02'].Payment.values
payment_data_03 = payment_data.set_index('play_date').loc['2022-03'].Payment.values


# 월별 데이터를 하나로 합치기
total_payment = np.array([payment_data_02, payment_data_03],dtype=object)

# 기존 고객들의 결제이력을 히스토그램으로 그리기
bins = np.linspace(0,50000,10)
plt.xlabel('Payment')
plt.ylabel('Count')
plt.hist(total_payment, bins, label=['2022-02', '2022-03'])
# Out:
# (array([[3219., 1089.,    0.,  545.,    0.,  266.,    0.,    0.,  246.],
#         [2976.,  978.,    0.,  501.,    0.,  300.,    0.,    0.,  280.]]),
#  array([    0.        ,  5555.55555556, 11111.11111111, 16666.66666667,
#         22222.22222222, 27777.77777778, 33333.33333333, 38888.88888889,
#         44444.44444444, 50000.        ]),
#  <a list of 2 BarContainer objects>)
